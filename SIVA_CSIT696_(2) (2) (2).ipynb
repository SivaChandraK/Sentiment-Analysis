# %%
import googleapiclient.discovery

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDRm7QjpHwFZyZhsICaog2JUaB89LLOLMw"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

channel_id = "UCxx4MuVpQxG9BtNfG3o8hGg"  # Replace with the actual channel ID you want to retrieve videos from

request = youtube.search().list(
    part="snippet",
    channelId=channel_id,
    maxResults=100
)
response = request.execute()

for item in response['items']:
    print(item['snippet']['title'])
# Out:
# STRAW HAT PIRATES VS BLACKBEARD PIRATES #onepiece #shorts
# ALL ONE PIECE LIVE ACTION CAST PART 1 #onepiece #shorts
# STRAW HAT PIRATES IN THE FUTURE #onepiece #shorts
# All 12 Members of Red Hair Pirates, Explained!
# 8 SPECIAL DEVIL FRUITS IN ONE PIECE #onepiece #shorts
# All 10 of Zoro Swords in One Piece, Explained
# The Great Power (Intensity) that Daemon Felt inside Himawari!
# Explaining detail about Humphrey Bogard (Garp&#39;s Right-Hand Man)
# All 4 Basic and Advanced Techniques from Armament  Haki
# 4 Secrets that Robin Hides from Luffy
# Here&#39;s 5 Arcs After Wano by Eiichiro Oda
# The Real Connection Between Monkey D Dragon and Rocks D Xebec
# Finally! All 12 Devil Fruit Users in Blackbeard Pirates
# 5 Artificial Devil Fruits Created by Vegapunk
# All 15 Members of Revolutionary Army and Their Power Explained
# The Real Reason Why Makima Killed Power, EXPLAINED
# Benn Beckman who cut Eustass Kid&#39;s Left arm
# ALL OTSUTSUKI IN BORUTO #boruto #shorts
# ...

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDRm7QjpHwFZyZhsICaog2JUaB89LLOLMw"  # Replace with your actual API key

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

channel_id = "UCxx4MuVpQxG9BtNfG3o8hGg"  # Replace with the actual channel ID you want to retrieve videos from

# Retrieve videos from the channel
request = youtube.search().list(
    part="snippet",
    channelId=channel_id,
    maxResults=100
)
response = request.execute()

video_ids = []

for item in response['items']:
    if item['id'].get('videoId'):
        video_ids.append(item['id']['videoId'])

comments = []

# Iterate through each video and retrieve comments
for video_id in video_ids:
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100
    )
    response = request.execute()

    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([
            comment['authorDisplayName'],
            comment['publishedAt'],
            comment['updatedAt'],
            comment['textDisplay']
        ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'text'])

df.head(1000)
# Out:
#                      author          published_at            updated_at  \
# 0         @jnaneshwarip1611  2023-12-08T05:29:22Z  2023-12-08T05:29:22Z
# 1                @mennnn972  2023-12-04T02:17:02Z  2023-12-04T02:17:02Z
# 2          @user-eq9yz2yc5u  2023-11-10T11:35:05Z  2023-11-10T11:35:05Z
# 3            @almighty0.045  2023-11-08T07:02:01Z  2023-11-08T07:02:01Z
# 4         @masterofbeyz2529  2023-11-04T10:52:57Z  2023-11-04T10:52:57Z
# ..                      ...                   ...                   ...
# 995              @NACASH100  2022-08-10T10:42:11Z  2022-08-10T10:42:11Z
# 996        @edwarddavis8093  2022-08-09T22:52:42Z  2022-08-09T22:52:42Z
# 997  @haneyjr.balindong3109  2022-08-09T08:56:11Z  2022-08-09T08:56:11Z
# 998           @yxngmari9529  2022-08-09T03:52:08Z  2022-08-09T03:52:08Z
# 999             @Nonskiller  2022-08-08T18:20:53Z  2022-08-08T18:21:11Z
#
#                                                   text
# ...

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDRm7QjpHwFZyZhsICaog2JUaB89LLOLMw"  # Replace with your actual API key

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

channel_id = "UCxx4MuVpQxG9BtNfG3o8hGg"  # Replace with the actual channel ID you want to retrieve videos from

# Retrieve videos from the channel
request = youtube.search().list(
    part="snippet",
    channelId=channel_id,
    maxResults=100
)
response = request.execute()

video_data = []

for item in response['items']:
    if item['id'].get('videoId'):
        video_id = item['id']['videoId']

        # Iterate through each video and retrieve comments
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100
        )
        comments_response = request.execute()

        for comment_item in comments_response['items']:
            comment = comment_item['snippet']['topLevelComment']['snippet']
            video_data.append([
                video_id,
                comment['publishedAt'],
                comment['authorDisplayName'],
                comment['textDisplay']
            ])

# Create a DataFrame
df = pd.DataFrame(video_data, columns=['VideoID', 'CommentDate', 'Author', 'Content'])

# Display the first 1000 rows
df.head(1000)
# Out:
#          VideoID           CommentDate                  Author  \
# 0    ie88Iqbrya4  2023-12-08T05:29:22Z       @jnaneshwarip1611
# 1    ie88Iqbrya4  2023-12-04T02:17:02Z              @mennnn972
# 2    ie88Iqbrya4  2023-11-10T11:35:05Z        @user-eq9yz2yc5u
# 3    ie88Iqbrya4  2023-11-08T07:02:01Z          @almighty0.045
# 4    ie88Iqbrya4  2023-11-04T10:52:57Z       @masterofbeyz2529
# ..           ...                   ...                     ...
# 995  CyjcMmo6G_Y  2022-08-10T10:42:11Z              @NACASH100
# 996  CyjcMmo6G_Y  2022-08-09T22:52:42Z        @edwarddavis8093
# 997  CyjcMmo6G_Y  2022-08-09T08:56:11Z  @haneyjr.balindong3109
# 998  CyjcMmo6G_Y  2022-08-09T03:52:08Z           @yxngmari9529
# 999  CyjcMmo6G_Y  2022-08-08T18:20:53Z             @Nonskiller
#
#                                                Content
# 0                         Black beard pirates will win
# 1    What is blackbeard mumbling about in the backg...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2062 entries, 0 to 2061
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   VideoID      2062 non-null   object
#  1   CommentDate  2062 non-null   object
#  2   Author       2062 non-null   object
#  3   Content      2062 non-null   object
# dtypes: object(4)
# memory usage: 64.6+ KB

# %%
comment_text = df['Content']
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all comments into a single string
combined_text = " ".join(comment for comment in comment_text)

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(combined_text)

# Display the word cloud using Matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDRm7QjpHwFZyZhsICaog2JUaB89LLOLMw"  # Replace with your actual API key

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

channel_id = "UCxx4MuVpQxG9BtNfG3o8hGg"  # Replace with the actual channel ID you want to retrieve videos from

# Create a DataFrame to store video data
video_data = []

# Retrieve videos from the channel
request = youtube.search().list(
    part="snippet",
    channelId=channel_id,
    maxResults=100
)
response = request.execute()

for item in response['items']:
    if item['id'].get('videoId'):
        video_id = item['id']['videoId']

        # Retrieve video statistics
        video_request = youtube.videos().list(
            part="statistics,snippet",
            id=video_id
        )
        video_response = video_request.execute()

        video_info = video_response['items'][0]

        video_date = video_info['snippet']['publishedAt']

        # Check if 'likeCount' statistic exists in video_info
        like_count = video_info['statistics'].get('likeCount', 0)
        comment_count = video_info['statistics'].get('commentCount', 0)
        view_count = video_info['statistics'].get('viewCount', 0)
        video_data.append([
            video_id,
            video_date,
            like_count,
            comment_count,
            view_count


        ])

# Create a DataFrame for video information
video_df = pd.DataFrame(video_data, columns=['VideoID', 'VideoDate', 'LikeCount', 'CommentCount', 'ViewCount'])

# Display the first few rows of the video DataFrame
video_df.head()
# Out:
#        VideoID             VideoDate LikeCount CommentCount ViewCount
# 0  xJtFu-A0dk8  2023-03-05T14:38:50Z      7876          245    169009
# 1  Y5JXrbS_LCI  2023-02-08T10:29:26Z     53615         1094    943207
# 2  xUUU3Jp9Fr0  2023-03-09T12:45:34Z       158            4     12505
# 3  6GmXu3SmrYU  2023-05-04T02:37:31Z       271           53     22080
# 4  RBhiarwF9SI  2022-12-09T12:31:28Z       506           30     19711

# %%
video_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   VideoID       50 non-null     object
#  1   VideoDate     50 non-null     object
#  2   LikeCount     50 non-null     object
#  3   CommentCount  50 non-null     object
#  4   ViewCount     50 non-null     object
# dtypes: object(5)
# memory usage: 2.1+ KB

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDRm7QjpHwFZyZhsICaog2JUaB89LLOLMw"  # Replace with your actual API key

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

channel_id = "UCxx4MuVpQxG9BtNfG3o8hGg"  # Replace with the actual channel ID you want to retrieve videos from

# Create a DataFrame to store video data
video_data = []

# Retrieve videos from the channel
request = youtube.search().list(
    part="snippet",
    channelId=channel_id,
    maxResults=100
)
response = request.execute()

for item in response['items']:
    if item['id'].get('videoId'):
        video_id = item['id']['videoId']

        # Retrieve video statistics
        video_request = youtube.videos().list(
            part="snippet,statistics",
            id=video_id
        )
        video_response = video_request.execute()

        video_info = video_response['items'][0]

        video_date = video_info['snippet']['publishedAt']
        like_count = video_info['statistics'].get('likeCount', 0)
        comment_count = video_info['statistics'].get('commentCount', 0)
        view_count = video_info['statistics'].get('viewCount', 0)
        video_description = video_info['snippet'].get('description', '')  # Get video description
        video_title = video_info['snippet'].get('title', '')

        video_data.append([
            video_id,
            video_title,
            video_description,
            video_date,
            like_count,
            comment_count,
            view_count,
             # Add video description to the data
        ])

# Create a DataFrame for video information
video_df = pd.DataFrame(video_data, columns=['VideoID','Video_title', 'VideoDescription', 'VideoDate', 'LikeCount', 'CommentCount', 'ViewCount'])

# Display the first few rows of the video DataFrame
video_df.head()
# Out:
#        VideoID                                        Video_title  \
# 0  LvcSgeHG3FQ     All 12 Members of Red Hair Pirates, Explained!
# 1  xUUU3Jp9Fr0      All 10 of Zoro Swords in One Piece, Explained
# 2  D7riuDqvkxQ  The Great Power (Intensity) that Daemon Felt i...
# 3  6GmXu3SmrYU  Explaining detail about Humphrey Bogard (Garp'...
# 4  RBhiarwF9SI  All 4 Basic and Advanced Techniques from Armam...
#
#                                     VideoDescription             VideoDate  \
# 0  Video title : All 12 Members of Red Hair Pirat...  2023-03-03T18:47:11Z
# 1  Video title : All 10 of Zoro Swords in One Pie...  2023-03-09T12:45:34Z
# 2  Video title : The Great Power (Intensity) that...  2023-03-21T13:14:41Z
# 3  Video title : Explaining detail about Humphrey...  2023-05-04T02:37:31Z
# 4  Haki ability is one of the main sources of pow...  2022-12-09T12:31:28Z
#
#   LikeCount CommentCount ViewCount
# 0       816           43     59919
# 1       158            4     12505
# ...

# %%
video_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   VideoID           50 non-null     object
#  1   Video_title       50 non-null     object
#  2   VideoDescription  50 non-null     object
#  3   VideoDate         50 non-null     object
#  4   LikeCount         50 non-null     object
#  5   CommentCount      50 non-null     object
#  6   ViewCount         50 non-null     object
# dtypes: object(7)
# memory usage: 2.9+ KB

# %%
# !pip install nltk
import nltk
nltk.download('vader_lexicon')
# Out:
# ...
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# Initialize the sentiment analyzer
sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('Luffy is awesome')
# Out:
# {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6249}

# %%
# Assuming you have a DataFrame 'df' with the specified columns
comments = df['Content']

# Create a list to store sentiment scores
sentiment_scores = []

# Analyze sentiment for each comment
for comment in comments:
    sentiment_score = sia.polarity_scores(comment)
    sentiment_scores.append(sentiment_score)

# Create a new DataFrame with sentiment scores
sentiment_df = pd.DataFrame(sentiment_scores)

# Concatenate the sentiment DataFrame with the original DataFrame
result_df = pd.concat([df, sentiment_df], axis=1)

# Display the result DataFrame with sentiment scores
result_df.head()
# Out:
#        VideoID           CommentDate             Author  \
# 0  ie88Iqbrya4  2023-12-08T05:29:22Z  @jnaneshwarip1611
# 1  ie88Iqbrya4  2023-12-04T02:17:02Z         @mennnn972
# 2  ie88Iqbrya4  2023-11-10T11:35:05Z   @user-eq9yz2yc5u
# 3  ie88Iqbrya4  2023-11-08T07:02:01Z     @almighty0.045
# 4  ie88Iqbrya4  2023-11-04T10:52:57Z  @masterofbeyz2529
#
#                                              Content  neg    neu    pos  \
# 0                       Black beard pirates will win  0.0  0.513  0.487
# 1  What is blackbeard mumbling about in the backg...  0.0  1.000  0.000
# 2  Obviously the straw hats win but it&#39;s shad...  0.0  0.833  0.167
# 3                                   Kuzan: Ice Age 🗿  0.0  1.000  0.000
# 4                                             Bb 7-3  0.0  1.000  0.000
#
#    compound
# 0    0.5859
# 1    0.0000
# 2    0.3400
# 3    0.0000
# 4    0.0000

# %%
result_df.columns
# Out:
# Index(['VideoID', 'CommentDate', 'Author', 'Content', 'neg', 'neu', 'pos',
#        'compound'],
#       dtype='object')

# %%
import seaborn as sns
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16, 4))

# List of sentiment categories
sentiments = ['neg', 'neu', 'pos', 'compound']

# Create histograms for each sentiment category
for i, sentiment in enumerate(sentiments):
    sns.histplot(result_df[sentiment], ax=axes[i], kde=True, bins=20)
    axes[i].set_title(f'{sentiment.capitalize()} Sentiment')

plt.tight_layout()
plt.show()

# %%
df2 = result_df.groupby('VideoID')['compound'].mean()
df2
# Out:
# VideoID
# -0Ia6yeyvvk   -0.232333
# 1yCAhNApoLM   -0.149450
# 20PdQvrbD3I    0.376613
# 2paLCCSzAbA    0.358586
# 3aHawIyd4NI    0.018843
# 5-zANcBur8k    0.052955
# 6GmXu3SmrYU    0.089052
# 6aIkWtQtCOc    0.238200
# 79sLjuONRLE    0.219575
# 7tDR5rBQtTE    0.132833
# CgNcmxDRQhE    0.059978
# CyjcMmo6G_Y    0.111665
# D7riuDqvkxQ    0.189489
# GvChG_o0PVc    0.166200
# HjENVW0Dqto    0.358964
# L9TbGBhrCfc   -0.109531
# LMZopU57m5w   -0.010045
# LvcSgeHG3FQ    0.078127
# OowNuIJv5gs    0.058986
# Ptq1UIsu6u0   -0.045191
# QtZfA4llGOM    0.056180
# RBhiarwF9SI    0.151400
# UhjCmCJkYRw   -0.026363
# WLbmH65stYI    0.419938
# Y5JXrbS_LCI    0.044105
# bGrQo7GyHS4    0.177165
# bOiInetWRRg    0.021184
# bzKwzMPJ2Rc    0.193401
# c2tc7VdPITY   -0.053355
# chXx6jyrCtE    0.180314
# dv-QE8lB5W0   -0.039762
# e7s1XiOmDPk   -0.000856
# hKkG94i3SDQ    0.075015
# ie88Iqbrya4   -0.085522
# jKwmVTv12OA    0.153575
# k6UJ1tzQQ0Y    0.044894
# kk0zaArGfUk   -0.134633
# m8scNX2XevY    0.147703
# ...

# %%
df3 = df2.reset_index().rename(columns = {'index':'VideoID',0:'compound_mean'})

# %%
df3.columns
# Out:
# Index(['VideoID', 'compound'], dtype='object')

# %%
df3 = df3.rename(columns ={'compound':'compound_mean'})

# %%
df3.columns
# Out:
# Index(['VideoID', 'compound_mean'], dtype='object')

# %%
# !pip install plotly
import plotly.express as px  # For simplified plotting
# or
import plotly.graph_objs as go  # For more control and customization
fig = px.scatter(df2,  title='My Scatter Plot')
fig.show()
# Out:
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df2,  title='My Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df3=df3.sort_values(by='compound_mean',ascending = False)

# %%
df3['rank'] = df3['compound_mean'].rank( ascending = False)

# %%
df3.set_index('rank', inplace= True)

# %%
df3
# Out:
#           VideoID  compound_mean
# rank
# 1.0   WLbmH65stYI       0.419938
# 2.0   20PdQvrbD3I       0.376613
# 3.0   HjENVW0Dqto       0.358964
# 4.0   2paLCCSzAbA       0.358586
# 5.0   uuIZA4mNX3c       0.355500
# 6.0   6aIkWtQtCOc       0.238200
# 7.0   79sLjuONRLE       0.219575
# 8.0   bzKwzMPJ2Rc       0.193401
# 9.0   D7riuDqvkxQ       0.189489
# 10.0  chXx6jyrCtE       0.180314
# 11.0  bGrQo7GyHS4       0.177165
# 12.0  GvChG_o0PVc       0.166200
# 13.0  jKwmVTv12OA       0.153575
# 14.0  RBhiarwF9SI       0.151400
# 15.0  m8scNX2XevY       0.147703
# 16.0  7tDR5rBQtTE       0.132833
# 17.0  xUUU3Jp9Fr0       0.118850
# 18.0  zZ287ZayaB4       0.118524
# 19.0  CyjcMmo6G_Y       0.111665
# 20.0  r1CiT4DSxC8       0.095647
# 21.0  6GmXu3SmrYU       0.089052
# 22.0  y0eujmvBSAA       0.083807
# 23.0  v_KHxguc5XQ       0.081035
# 24.0  LvcSgeHG3FQ       0.078127
# 25.0  hKkG94i3SDQ       0.075015
# 26.0  pUTHP2yZbXA       0.070922
# 27.0  yG3IGk8qUC8       0.065293
# ...

# %%
video_title = video_df[['VideoID','Video_title']]

# %%
video_title
# Out:
#         VideoID                                        Video_title
# 0   LvcSgeHG3FQ     All 12 Members of Red Hair Pirates, Explained!
# 1   xUUU3Jp9Fr0      All 10 of Zoro Swords in One Piece, Explained
# 2   D7riuDqvkxQ  The Great Power (Intensity) that Daemon Felt i...
# 3   6GmXu3SmrYU  Explaining detail about Humphrey Bogard (Garp'...
# 4   RBhiarwF9SI  All 4 Basic and Advanced Techniques from Armam...
# 5   hKkG94i3SDQ              4 Secrets that Robin Hides from Luffy
# 6   chXx6jyrCtE  The Real Connection Between Monkey D Dragon an...
# 7   1yCAhNApoLM  Finally! All 12 Devil Fruit Users in Blackbear...
# 8   QtZfA4llGOM      5 Artificial Devil Fruits Created by Vegapunk
# 9   xaGpzEW5um8  All 15 Members of Revolutionary Army and Their...
# 10  -0Ia6yeyvvk  The Real Reason Why Makima Killed Power, EXPLA...
# 11  kk0zaArGfUk        Benn Beckman who cut Eustass Kid's Left arm
# 12  Y5JXrbS_LCI  STRAW HAT PIRATES IN THE FUTURE #onepiece #shorts
# ...

# %%
videos_list = df3.merge(video_title, on = 'VideoID', how = 'left')

# %%
videos_list
# Out:
#         VideoID  compound_mean  \
# 0   WLbmH65stYI       0.419938
# 1   20PdQvrbD3I       0.376613
# 2   HjENVW0Dqto       0.358964
# 3   2paLCCSzAbA       0.358586
# 4   uuIZA4mNX3c       0.355500
# 5   6aIkWtQtCOc       0.238200
# 6   79sLjuONRLE       0.219575
# 7   bzKwzMPJ2Rc       0.193401
# 8   D7riuDqvkxQ       0.189489
# 9   chXx6jyrCtE       0.180314
# 10  bGrQo7GyHS4       0.177165
# 11  GvChG_o0PVc       0.166200
# 12  jKwmVTv12OA       0.153575
# 13  RBhiarwF9SI       0.151400
# 14  m8scNX2XevY       0.147703
# 15  7tDR5rBQtTE       0.132833
# 16  xUUU3Jp9Fr0       0.118850
# 17  zZ287ZayaB4       0.118524
# 18  CyjcMmo6G_Y       0.111665
# 19  r1CiT4DSxC8       0.095647
# 20  6GmXu3SmrYU       0.089052
# 21  y0eujmvBSAA       0.083807
# 22  v_KHxguc5XQ       0.081035
# 23  LvcSgeHG3FQ       0.078127
# 24  hKkG94i3SDQ       0.075015
# 25  pUTHP2yZbXA       0.070922
# 26  yG3IGk8qUC8       0.065293
# 27  uVRUafDmQq0       0.061997
# 28  CgNcmxDRQhE       0.059978
# ...

# %%
sia.polarity_scores('Wororororo')
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
result_df['compound'].max()
# Out:
# 0.9958

# %%
result_df['compound'].min()
# Out:
# -0.9974

# %%
def classify_sentiment(row):
    if row['pos'] > row['neg'] and row['pos'] > row['neu']:
        return 'Positive'
    elif row['neg'] > row['pos'] and row['neg'] > row['neu']:
        return 'Negative'
    else:
        return 'Neutral'

result_df['Sentiment'] = result_df.apply(classify_sentiment, axis=1)

# %%
result_df.columns
# Out:
# Index(['VideoID', 'CommentDate', 'Author', 'Content', 'neg', 'neu', 'pos',
#        'compound', 'Sentiment'],
#       dtype='object')

# %%
# Sample data: Replace this with the result of value_counts from your DataFrame
data = result_df['Sentiment'].value_counts()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(data, labels=data.index, autopct='%1.1f%%', startangle=90, shadow=True)

# Add a title
plt.title('Distribution of Categories')

# Display the pie chart
plt.show()

# %%
data
# Out:
# Neutral     1899
# Positive     109
# Negative      54
# Name: Sentiment, dtype: int64

# %%
result_df
# Out:
#           VideoID           CommentDate                  Author  \
# 0     ie88Iqbrya4  2023-12-08T05:29:22Z       @jnaneshwarip1611
# 1     ie88Iqbrya4  2023-12-04T02:17:02Z              @mennnn972
# 2     ie88Iqbrya4  2023-11-10T11:35:05Z        @user-eq9yz2yc5u
# 3     ie88Iqbrya4  2023-11-08T07:02:01Z          @almighty0.045
# 4     ie88Iqbrya4  2023-11-04T10:52:57Z       @masterofbeyz2529
# ...           ...                   ...                     ...
# 2057  m8scNX2XevY  2021-03-19T17:10:07Z               @SS-qk3is
# 2058  m8scNX2XevY  2021-03-19T16:53:35Z  @Saint_MaX_ONeal_B_Rul
# 2059  m8scNX2XevY  2021-03-19T16:48:57Z          @papichulo4398
# 2060  m8scNX2XevY  2021-03-19T16:45:44Z             @ATuttoNerd
# 2061  m8scNX2XevY  2021-03-19T16:38:04Z        @crazypirate8448
#
#                                                 Content    neg    neu    pos  \
# 0                          Black beard pirates will win  0.000  0.513  0.487
# ...

# %%
df2.head()
# Out:
# VideoID
# -0Ia6yeyvvk   -0.232333
# 1yCAhNApoLM   -0.149450
# 20PdQvrbD3I    0.376613
# 2paLCCSzAbA    0.358586
# 3aHawIyd4NI    0.018843
# Name: compound, dtype: float64

# %%
df3 = result_df.groupby('VideoID')['compound'].mean().reset_index()
df3.head()
# Out:
#        VideoID  compound
# 0  -0Ia6yeyvvk -0.232333
# 1  1yCAhNApoLM -0.149450
# 2  20PdQvrbD3I  0.376613
# 3  2paLCCSzAbA  0.358586
# 4  3aHawIyd4NI  0.018843

# %%
df3['compound'].min()
# Out:
# -0.232333

# %%
def classify_compound(row):
    if row['compound'] > 0.05:
        return 'Positive'
    elif row['compound'] < -0.05:
        return 'Negative'
    else:
        return 'Neutral'

df3['Comment_Cat'] = df3.apply(classify_compound, axis=1)

# %%
df3
# Out:
#         VideoID  compound Comment_Cat
# 0   -0Ia6yeyvvk -0.232333    Negative
# 1   1yCAhNApoLM -0.149450    Negative
# 2   20PdQvrbD3I  0.376613    Positive
# 3   2paLCCSzAbA  0.358586    Positive
# 4   3aHawIyd4NI  0.018843     Neutral
# 5   5-zANcBur8k  0.052955    Positive
# 6   6GmXu3SmrYU  0.089052    Positive
# 7   6aIkWtQtCOc  0.238200    Positive
# 8   79sLjuONRLE  0.219575    Positive
# 9   7tDR5rBQtTE  0.132833    Positive
# 10  CgNcmxDRQhE  0.059978    Positive
# 11  CyjcMmo6G_Y  0.111665    Positive
# 12  D7riuDqvkxQ  0.189489    Positive
# 13  GvChG_o0PVc  0.166200    Positive
# 14  HjENVW0Dqto  0.358964    Positive
# 15  L9TbGBhrCfc -0.109531    Negative
# 16  LMZopU57m5w -0.010045     Neutral
# 17  LvcSgeHG3FQ  0.078127    Positive
# 18  OowNuIJv5gs  0.058986    Positive
# 19  Ptq1UIsu6u0 -0.045191     Neutral
# 20  QtZfA4llGOM  0.056180    Positive
# 21  RBhiarwF9SI  0.151400    Positive
# 22  UhjCmCJkYRw -0.026363     Neutral
# 23  WLbmH65stYI  0.419938    Positive
# ...

# %%
top_10 = df3['VideoID'].loc[:10]
top_10
# Out:
# 0     -0Ia6yeyvvk
# 1     1yCAhNApoLM
# 2     20PdQvrbD3I
# 3     2paLCCSzAbA
# 4     3aHawIyd4NI
# 5     5-zANcBur8k
# 6     6GmXu3SmrYU
# 7     6aIkWtQtCOc
# 8     79sLjuONRLE
# 9     7tDR5rBQtTE
# 10    CgNcmxDRQhE
# Name: VideoID, dtype: object

# %%
import re
def clean_comment(comment):
    # Remove non-alphanumeric characters and symbols, except spaces
    comment = re.sub(r'[^a-zA-Z0-9\s]', '', comment)

    # Convert to lowercase (optional)
    comment = comment.lower()

    return comment
comments = df['Content']
Cleaned_Comments = [clean_comment(comment) for comment in comments]
cleaned_df = pd.DataFrame(Cleaned_Comments, columns = ['Clean_Content'])
cleaned_df.head()
# Out:
#                                        Clean_Content
# 0                       black beard pirates will win
# 1  what is blackbeard mumbling about in the backg...
# 2  obviously the straw hats win but it39s shady t...
# 3                                     kuzan ice age
# 4                                              bb 73

# %%
result_df2 = pd.concat([result_df, cleaned_df], axis=1)
result_df2
# Out:
#           VideoID           CommentDate                  Author  \
# 0     ie88Iqbrya4  2023-12-08T05:29:22Z       @jnaneshwarip1611
# 1     ie88Iqbrya4  2023-12-04T02:17:02Z              @mennnn972
# 2     ie88Iqbrya4  2023-11-10T11:35:05Z        @user-eq9yz2yc5u
# 3     ie88Iqbrya4  2023-11-08T07:02:01Z          @almighty0.045
# 4     ie88Iqbrya4  2023-11-04T10:52:57Z       @masterofbeyz2529
# ...           ...                   ...                     ...
# 2057  m8scNX2XevY  2021-03-19T17:10:07Z               @SS-qk3is
# 2058  m8scNX2XevY  2021-03-19T16:53:35Z  @Saint_MaX_ONeal_B_Rul
# 2059  m8scNX2XevY  2021-03-19T16:48:57Z          @papichulo4398
# 2060  m8scNX2XevY  2021-03-19T16:45:44Z             @ATuttoNerd
# 2061  m8scNX2XevY  2021-03-19T16:38:04Z        @crazypirate8448
#
#                                                 Content    neg    neu    pos  \
# 0                          Black beard pirates will win  0.000  0.513  0.487
# ...

# %%
# Assuming you have a DataFrame 'df' with the specified columns
comments = result_df2['Content']

# Create a list to store sentiment scores
sentiment_scores = []

# Analyze sentiment for each comment
for comment in comments:
    sentiment_score = sia.polarity_scores(comment)
    sentiment_scores.append(sentiment_score)

# Create a new DataFrame with sentiment scores
sentiment_df = pd.DataFrame(sentiment_scores)

# Concatenate the sentiment DataFrame with the original DataFrame
result_df = pd.concat([df, sentiment_df], axis=1)

# Display the result DataFrame with sentiment scores
result_df.head()
# Out:
#        VideoID           CommentDate             Author  \
# 0  ie88Iqbrya4  2023-12-08T05:29:22Z  @jnaneshwarip1611
# 1  ie88Iqbrya4  2023-12-04T02:17:02Z         @mennnn972
# 2  ie88Iqbrya4  2023-11-10T11:35:05Z   @user-eq9yz2yc5u
# 3  ie88Iqbrya4  2023-11-08T07:02:01Z     @almighty0.045
# 4  ie88Iqbrya4  2023-11-04T10:52:57Z  @masterofbeyz2529
#
#                                              Content  neg    neu    pos  \
# 0                       Black beard pirates will win  0.0  0.513  0.487
# 1  What is blackbeard mumbling about in the backg...  0.0  1.000  0.000
# 2  Obviously the straw hats win but it&#39;s shad...  0.0  0.833  0.167
# 3                                   Kuzan: Ice Age 🗿  0.0  1.000  0.000
# 4                                             Bb 7-3  0.0  1.000  0.000
#
#    compound
# 0    0.5859
# 1    0.0000
# 2    0.3400
# 3    0.0000
# 4    0.0000

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.corpus import stopwords

# Define your own list of additional stopwords if needed
custom_stopwords = ["your", "custom", "stopwords"]

nltk.download('stopwords')


# Combine NLTK stopwords with custom stopwords
all_stopwords = set(stopwords.words("english") + custom_stopwords)

# Tokenize the cleaned text and remove stopwords
tokenized_comments = [
    [word for word in comment.split() if word not in all_stopwords]
    for comment in Cleaned_Comments
]

# Create a document-term matrix
vectorizer = CountVectorizer()
dtm = vectorizer.fit_transform([" ".join(comment) for comment in tokenized_comments])

# Apply LDA
lda_model = LatentDirichletAllocation(n_components=5, random_state=42)  # You can adjust the number of topics
lda_model.fit(dtm)

# Get the top words for each topic
feature_names = vectorizer.get_feature_names_out()
n_top_words = 10

for topic_idx, topic in enumerate(lda_model.components_):
    top_words_idx = topic.argsort()[-n_top_words:][::-1]
    top_words = [feature_names[i] for i in top_words_idx]
    print(f"Topic #{topic_idx}: {', '.join(top_words)}")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Topic #0: luffy, like, shanks, think, crews, dissolutionuntil, also, fruit, one, would
# Topic #1: luffy, dragon, roger, shanks, nami, rayleigh, robin, fruit, end, garp
# Topic #2: luffy, one, like, shanks, know, see, boruto, good, would, zoro
# Topic #3: one, piece, vs, power, mihawk, makima, still, luffy, shanks, buggy
# Topic #4: fruit, kaguya, otsutsuki, like, think, god, toneri, shibai, intro, brook

# %%
df.head()
# Out:
#        VideoID           CommentDate             Author  \
# 0  ie88Iqbrya4  2023-12-08T05:29:22Z  @jnaneshwarip1611
# 1  ie88Iqbrya4  2023-12-04T02:17:02Z         @mennnn972
# 2  ie88Iqbrya4  2023-11-10T11:35:05Z   @user-eq9yz2yc5u
# 3  ie88Iqbrya4  2023-11-08T07:02:01Z     @almighty0.045
# 4  ie88Iqbrya4  2023-11-04T10:52:57Z  @masterofbeyz2529
#
#                                              Content
# 0                       Black beard pirates will win
# 1  What is blackbeard mumbling about in the backg...
# 2  Obviously the straw hats win but it&#39;s shad...
# 3                                   Kuzan: Ice Age 🗿
# 4                                             Bb 7-3

# %%
df.dtypes
# Out:
# VideoID        object
# CommentDate    object
# Author         object
# Content        object
# dtype: object

# %%
#Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# Import functions for data preprocessing & data preparation
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from sklearn.feature_extraction.text import CountVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer, LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
import string
from string import punctuation
import nltk
import re

# %%
nltk.download('vader_lexicon')
sentiments = SentimentIntensityAnalyzer()
result_df2["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in result_df2["Clean_Content"]]
result_df2["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in result_df2["Clean_Content"]]
result_df2["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in result_df2["Clean_Content"]]
result_df2['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in result_df2["Clean_Content"]]
score = result_df2["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
result_df2["Sentiment"] = sentiment
result_df2.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#        VideoID           CommentDate             Author  \
# 0  ie88Iqbrya4  2023-12-08T05:29:22Z  @jnaneshwarip1611
# 1  ie88Iqbrya4  2023-12-04T02:17:02Z         @mennnn972
# 2  ie88Iqbrya4  2023-11-10T11:35:05Z   @user-eq9yz2yc5u
# 3  ie88Iqbrya4  2023-11-08T07:02:01Z     @almighty0.045
# 4  ie88Iqbrya4  2023-11-04T10:52:57Z  @masterofbeyz2529
#
#                                              Content  neg    neu    pos  \
# 0                       Black beard pirates will win  0.0  0.513  0.487
# 1  What is blackbeard mumbling about in the backg...  0.0  1.000  0.000
# 2  Obviously the straw hats win but it&#39;s shad...  0.0  0.833  0.167
# 3                                   Kuzan: Ice Age 🗿  0.0  1.000  0.000
# 4                                             Bb 7-3  0.0  1.000  0.000
#
# ...

# %%
data2=result_df2[['Clean_Content','Sentiment']]
data2.head()
# Out:
#                                        Clean_Content Sentiment
# 0                       black beard pirates will win  Positive
# 1  what is blackbeard mumbling about in the backg...   Neutral
# 2  obviously the straw hats win but it39s shady t...  Positive
# 3                                     kuzan ice age    Neutral
# 4                                              bb 73   Neutral

# %%
stop_words = stopwords.words('english')
porter_stemmer = PorterStemmer()
lancaster_stemmer = LancasterStemmer()
snowball_stemer = SnowballStemmer(language="english")
lzr = WordNetLemmatizer()

# %%
def text_processing(text):
    # convert text into lowercase
    text = text.lower()

    # remove new line characters in text
    text = re.sub(r'\n',' ', text)

    # remove punctuations from text
    text = re.sub('[%s]' % re.escape(punctuation), "", text)

    # remove references and hashtags from text
    text = re.sub("^a-zA-Z0-9$,.", "", text)

    # remove multiple spaces from text
    text = re.sub(r'\s+', ' ', text, flags=re.I)

    # remove special characters from text
    text = re.sub(r'\W', ' ', text)

    text = ' '.join([word for word in word_tokenize(text) if word not in stop_words])

    # stemming using porter stemmer from nltk package - msh a7sn 7aga - momken: lancaster, snowball
    # text=' '.join([porter_stemmer.stem(word) for word in word_tokenize(text)])
    # text=' '.join([lancaster_stemmer.stem(word) for word in word_tokenize(text)])
    # text=' '.join([snowball_stemer.stem(word) for word in word_tokenize(text)])

    # lemmatizer using WordNetLemmatizer from nltk package
    text=' '.join([lzr.lemmatize(word) for word in word_tokenize(text)])

    return text

# %%
nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download('wordnet')

data_copy = data2.copy()
data_copy['Clean_Content'] = data_copy['Clean_Content'].apply(lambda text: text_processing(text))
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
data_copy.head()
# Out:
#                                        Clean_Content Sentiment
# 0                             black beard pirate win  Positive
# 1                     blackbeard mumbling background   Neutral
# 2  obviously straw hat win it39s shady nami doesn...  Positive
# 3                                      kuzan ice age   Neutral
# 4                                              bb 73   Neutral

# %%
sentiment_mapping = {'Positive': 2, 'Neutral': 1, 'Negative': 0}
data_copy['Sentiment'] = data_copy['Sentiment'].map(sentiment_mapping)

# %%
data_copy
# Out:
#                                           Clean_Content  Sentiment
# 0                                black beard pirate win          2
# 1                        blackbeard mumbling background          1
# 2     obviously straw hat win it39s shady nami doesn...          2
# 3                                         kuzan ice age          1
# 4                                                 bb 73          1
# ...                                                 ...        ...
# 2057  hrefhttpswwwyoutubecomwatchvm8scnx2xevyampt3m5...          1
# 2058      ofc rayleigh strongerroger even breathing lol          0
# 2059  like buggy said bullet strong silver king rayl...          2
# 2060                                 god usopp stronger          2
# 2061               lol bro add thrash topic video sense          2
#
# [2062 rows x 2 columns]

# %%
processed_data = {
    'Sentence':data_copy['Clean_Content'],
    'Sentiment':data_copy['Sentiment']
}

processed_data = pd.DataFrame(processed_data)
processed_data.head()
# Out:
#                                             Sentence  Sentiment
# 0                             black beard pirate win          2
# 1                     blackbeard mumbling background          1
# 2  obviously straw hat win it39s shady nami doesn...          2
# 3                                      kuzan ice age          1
# 4                                              bb 73          1

# %%
processed_data['Sentiment'].value_counts()
# Out:
# 1    848
# 2    701
# 0    513
# Name: Sentiment, dtype: int64

# %%
from sklearn.utils import resample

df_neutral = processed_data[(processed_data['Sentiment']==1)]
df_negative = processed_data[(processed_data['Sentiment']==0)]
df_positive = processed_data[(processed_data['Sentiment']==2)]


# Upsample the neutral and negative sentiments to 250 samples each
df_negative_upsampled = resample(df_negative,
                                 replace=True,
                                 n_samples=599,
                                 random_state=42)

df_neutral_upsampled = resample(df_neutral,
                                replace=False,
                                n_samples=599,
                                random_state=42)
df_positive_unsampled = resample(df_positive,
                                replace=False,
                                n_samples=599,
                                random_state=42)


# Concatenate the upsampled and downsampled dataframes
final_data = pd.concat([df_negative_upsampled, df_neutral_upsampled, df_positive_unsampled])

# %%
final_data['Sentiment'].value_counts()
# Out:
# 0    599
# 1    599
# 2    599
# Name: Sentiment, dtype: int64

# %%
final_data.columns
# Out:
# Index(['Sentence', 'Sentiment'], dtype='object')

# %%
corpus = []
for sentence in final_data['Sentence']:
    corpus.append(sentence)
corpus[0:5]
# Out:
# ['didn39t know luffy robin brother sister child rock dragon shocked let39s see many fan know dragon real name nico luffy relationship',
#  'film red shank crew beast combat even doctor ship',
#  'buggy dont show full power former member pirate king also ate devil fruit child like luffy luffy show power buggy dont',
#  '4 secret robin hide luffy',
#  'luffy bad']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=150)
X = cv.fit_transform(corpus).toarray()
y = final_data.iloc[:, -1].values

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 56,  60,  18],
#        [  1, 106,   6],
#        [ 13,  73,  27]])

# %%
nb_score = accuracy_score(y_test, y_pred)
print('accuracy',nb_score)
# Out:
# accuracy 0.525

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# %%
n_score = accuracy_score(y_test, y_pred)
print('accuracy',n_score)
# Out:
# accuracy 0.5694444444444444

# %%
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression(multi_class='ovr')  # or multi_class='multinomial' for softmax regression
model1.fit(X_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
y_pred1 = model1.predict(X_test)
cm = confusion_matrix(y_test, y_pred1)
cm
# Out:
# array([[75, 42, 17],
#        [ 7, 94, 12],
#        [20, 39, 54]])

# %%
n1_score = accuracy_score(y_test, y_pred1)
print('accuracy',n1_score)
# Out:
# accuracy 0.6194444444444445

# %%
from sklearn.svm import SVC
model2 = SVC(kernel='linear', decision_function_shape='ovr')
model2.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred2 = model2.predict(X_test)
cm = confusion_matrix(y_test, y_pred2)
cm
# Out:
# array([[88, 31, 15],
#        [14, 92,  7],
#        [25, 35, 53]])

# %%
n2_score = accuracy_score(y_test, y_pred2)
print('accuracy',n2_score)
# Out:
# accuracy 0.6472222222222223

# %%
from sklearn.ensemble import RandomForestClassifier
model3 = RandomForestClassifier()
model3.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = model3.predict(X_test)
cm = confusion_matrix(y_test, y_pred3)
cm
# Out:
# array([[98, 26, 10],
#        [17, 77, 19],
#        [14, 33, 66]])

# %%
n3_score = accuracy_score(y_test, y_pred3)
print('accuracy',n3_score)
# Out:
# accuracy 0.6694444444444444

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# Assuming your texts is a list of sentences
texts = processed_data['Sentence']

# Create a tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

# Get the vocabulary size
vocab_size = len(tokenizer.word_index) + 1  # Adding 1 for the reserved index 0
print(vocab_size)
# Out:
# 4712

# %%
# Example using TensorFlow and Keras for an LSTM-based model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

model4 = Sequential()
model4.add(Embedding(input_dim=vocab_size, output_dim=50, input_length=150))
model4.add(LSTM(100))
model4.add(Dense(3, activation='softmax'))

# %%
# Compile the model
model4.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model4.fit(X_train, y_train, epochs=30, batch_size=40, validation_split=0.2)
# Out:
# Epoch 1/30
# 31/31 [==============================] - 10s 225ms/step - loss: 1.0990 - accuracy: 0.3588 - val_loss: 1.0972 - val_accuracy: 0.3421
# Epoch 2/30
# 31/31 [==============================] - 7s 233ms/step - loss: 1.0951 - accuracy: 0.3737 - val_loss: 1.1002 - val_accuracy: 0.3421
# Epoch 3/30
# 31/31 [==============================] - 10s 325ms/step - loss: 1.0942 - accuracy: 0.3737 - val_loss: 1.0942 - val_accuracy: 0.3421
# Epoch 4/30
# 31/31 [==============================] - 6s 203ms/step - loss: 1.1020 - accuracy: 0.3679 - val_loss: 1.0949 - val_accuracy: 0.4375
# Epoch 5/30
# 31/31 [==============================] - 7s 218ms/step - loss: 1.0934 - accuracy: 0.3720 - val_loss: 1.0958 - val_accuracy: 0.3421
# Epoch 6/30
# 31/31 [==============================] - 7s 231ms/step - loss: 1.0922 - accuracy: 0.3737 - val_loss: 1.0947 - val_accuracy: 0.3454
# Epoch 7/30
# ...

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model4.evaluate(X_test, y_test)

# Print the test loss and accuracy
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 12/12 [==============================] - 0s 37ms/step - loss: 1.0297 - accuracy: 0.4316
# Test Loss: 1.0297
# Test Accuracy: 43.16%
